# %% [markdown]
# <a href="https://colab.research.google.com/github/saqibyafi20/Python_Practice/blob/main/List_Comprehension.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Create a list of squares of numbers from 1 to 10.

# %%
squares = [x*x for x in range(1, 11)]
squares
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
# Extract even numbers from a list.

# %%
nums = [1,2,3,4,5,6,7,8]
evens = [x for x in nums if x % 2 == 0]
evens
# Out:
# [2, 4, 6, 8]

# %%
# Convert all strings to uppercase.

# %%
names = ["saqib", "yafi", "python"]
upper_names = [name.upper() for name in names]
upper_names
# Out:
# ['SAQIB', 'YAFI', 'PYTHON']

# %%
# Create a list of numbers divisible by 3 in range 1–50.

# %%
div_by_3 = [x for x in range(1, 51) if x % 3 == 0]
div_by_3
# Out:
# [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48]

# %%
# Get first letter of each word.

# %%
words = ["apple", "banana", "cat"]
first_letters = [w[0] for w in words]
first_letters
# Out:
# ['a', 'b', 'c']

# %%
# Reverse each string in a list.

# %%
words = ["hello", "python"]
rev = [w[::-1] for w in words]
rev
# Out:
# ['olleh', 'nohtyp']
