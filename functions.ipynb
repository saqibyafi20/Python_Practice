# %% [markdown]
# <a href="https://colab.research.google.com/github/saqibyafi20/Python_Practice/blob/main/functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Write a function that returns the maximum of two numbers.

# %%
def maxi(a, b):
    return a if a > b else b

print(max(5, 9))
# Out:
# 9

# %%
# Write a function to check whether a number is prime.

# %%
def is_prime(n):
    if n <= 1:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

print(is_prime(13))
# Out:
# True

# %%
# Write a function that returns the factorial of a number.

# %%
def factorial(n):
    if n == 0 or n == 1:
        return 1
    return n * factorial(n - 1)

print(factorial(5))  # 120
# Out:
# 120

# %%
# Write a function that counts vowels in a string.

# %%
def count_vowels(s):
    vowels = "aeiouAEIOU"
    return sum(1 for char in s if char in vowels)

print(count_vowels("ChatGPT"))
# Out:
# 1

# %%
# average of two numbers.

# %%
def average_numbers(*num):
    sum=0
    for i in num:
        sum=sum+i
    print("average is", sum / len(num) )


print(average_numbers(10,5))
# Out:
# average is 7.5
# None

# %%
# create a function to convert celcius into fahrenheit

# %%
def fahrenheit(celsius):
    return (celsius*9/5)+ 32

a=fahrenheit(25)
print(a)
# Out:
# 77.0
