# %%
print("\n######## WELCOME TO KAUN BANEGA CROREPATI ########")
questions=[
    ['Q1: independence day in india is celebrated on','15 aug','20 sep','30 jan','21 march',1],
    ['Q2: republic day in india celebrated on','21 april','16 jan','26 jan','13 july',3],
    ['Q3: capital of india is', 'j&k','chennai','mumbai','delhi',4],
    ['Q4: CM of j & k is','Modi','rahul','umer abdullah','pandey',3],
    ['Q5: Who is known as Father of Nation','JawaharLal Nehru','Chandra Bose','Mahatma Gandhi','Bhagat Singh',3],
    ['Q6: Which planet is known as red planet','Earth','Venus','Mars','Jupiter',3]
    ]
values=[1000,2000,8000,15000,30000,50000]
money=0

for i in range(0,len(questions)):
    print(f'question for Rs. {values[i]}')
    print (questions[i][0])
    print(f'a. {questions[i][1]}                  b.{questions[i][2]}')
    print(f'c. {questions[i][3]}                  d.{questions[i][4]}')
    ans=int(input('enter your answer(1-4)'))
    if ans == questions[i][-1]:
        print(f'correct answer you have won {values[i]}')
        money = money + (values[i])
    else:
        print ('\nincorrect answer')
        break
print(f'\ntotal money you have won {money}')
# Out:
# ######## WELCOME TO KAUN BANEGA CROREPATI ########
# question for Rs. 1000
# Q1: independence day in india is celebrated on
# a. 15 aug                  b.20 sep
# c. 30 jan                  d.21 march
# correct answer you have won 1000
# question for Rs. 2000
# Q2: republic day in india celebrated on
# a. 21 april                  b.16 jan
# c. 26 jan                  d.13 july
# correct answer you have won 2000
# question for Rs. 8000
# Q3: capital of india is
# a. j&k                  b.chennai
# c. mumbai                  d.delhi
# correct answer you have won 8000
# question for Rs. 15000
# Q4: CM of j & k is
# a. Modi                  b.rahul
# c. umer abdullah                  d.pandey
# correct answer you have won 15000
# question for Rs. 30000
# Q5: Who is known as Father of Nation
# a. JawaharLal Nehru                  b.Chandra Bose
# c. Mahatma Gandhi                  d.Bhagat Singh
# correct answer you have won 30000
# question for Rs. 50000
# ...
