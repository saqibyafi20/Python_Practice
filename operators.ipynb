# %% [markdown]
# <a href="https://colab.research.google.com/github/saqibyafi20/Python_Practice/blob/main/operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ARITHMETIC OPERATORS

# %%
# Compute (a + b) * c .

# %%
a, b, c = 2, 3, 4
result = (a + b) * c
result
# Out:
# 20

# %%
# Find Remainder of 17 ÷ 4 .

# %%
result = 17 % 4
result
# Out:
# 1

# %%
# Find 2 to the Power 5 .

# %%
result = 2 ** 5
result
# Out:
# 32

# %%
# Relational / Comparison Operators

# %%
# Check if a Number is Greater Than Another

# %%
a, b = 10, 8
result = a > b
result
# Out:
# True

# %%
# Check if Two Strings are Equal

# %%
result = "python" == "python"
result
# Out:
# True

# %%
# Check if 5 is Not Equal to 10

# %%
result = 5 != 10
result
# Out:
# True

# %%
# Check if Age is Between 18 and 60

# %%
age = 25
result = 18 <= age <= 60
result
# Out:
# True

# %%
# Assignment Operators

# %%
# Use += to Add 10 to a Number

# %%
x = 5
x += 10
x
# Out:
# 15

# %%
# Use -= to Decrease Value

# %%
x = 20
x -= 5
x
# Out:
# 15

# %%
# Membership Operators

# %%
# Check if Value Exists in List

# %%
nums = [1,2,3,4]
result = 3 in nums
result
# Out:
# True

# %%
# Check if Character Not in String

# %%
result = "z" not in "python"
result
# Out:
# True
